# %% [markdown]
# # Day 1: Handling Data
#
# ### MGMT 675, AI-Assisted Financial Analysis
# ### Kerry Back, JGSB, Rice University

# %% [markdown]
# ### ChatGPT + Python
#
# - Julius will execute code generated by ChatGPT and provide links to outputs.
# - Can output images, Excel tables, csv files, ...
# - We can also copy code from Julius and paste into a Jupyter notebook - for example, in Google Colab
# - We can save Colab notebooks to Google Drive and then reload them into Colab and run them whenever we want.

# %% [markdown]
# ### Today
#
# - Working with our own data
#   - Upload wages.csv to Julius

# %% [markdown]
# ### Online data
#
# - Yahoo Finance
#   - Prices
#   - Company financials
#   - Options
# - Federal Reserve Economic Data
# - SEC Edgar
# - Ken French's Data Library
# - Energy Information Administration
# - World Bank
# - Miscellaneous tables
# - Can get all of this data by clicking on webpages instead of using ChatGPT + Python but ChatGPT + Python is faster for repeated use.

# %% [markdown]
# ### Yahoo Finance
#
# - May need to tell ChatGPT to use yfinance module.
# - Open, high, low, close, adjusted close, volume
# - Adjusted close is split and dividend adjusted
# - Can compute close-to-close returns as percent change in adjusted close (= capital gain + dividend return)

# %% [markdown]
# - Data is downloaded as pandas dataframe
# - Can compute returns, moving averages, ...
# - Can generate plots
# - Can save data to Excel or csv files
# - Can save plots as jpeg, png, ...

# %% [markdown]
# ### Chat with Julius
#
# - Get adjusted closing prices for several tickers
# - Compute daily returns
# - Save as Excel file

# %% [markdown]
# ### Chat with Julius
#
# - Get income statements and balance sheets for several tickers
# - Compute ROE as net income divided by average (current and prior year) shareholders' equity

# %% [markdown]
# ### Chat with Julius
#
# - Get market call and put option data for some ticker/maturity.

# %% [markdown]
# ### Federal

# %%
###
